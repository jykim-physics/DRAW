# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math#
#import uproot
#from b2plot import hist
import b2plot as bp
import ROOT
#from root_pandas import read_root

import seaborn as sns
try:
    #plt.style.use('belle2')
    #plt.style.use('belle2_serif')
    plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
    
print(plt.style.available)
px = 1/plt.rcParams['figure.dpi']

##############################################

def get_data(file='file', figname='name', tree='tree', base_filter=None,variables=None):
    
    tree=tree
    f = file
    base_filter  = base_filter    
    
    ROOT_df_start = ROOT.RDataFrame(tree, f)  
    col_dict  = ROOT_df_start.AsNumpy(variables)
    
    if base_filter !=None:
        ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)                            
        col_dict  = ROOT_df_filtered.AsNumpy(variables)
    
    pd_df  = pd.DataFrame(col_dict)
    
    return pd_df
# Out:
# For optimal usage set `plt.style.use('belle2')`
# Welcome to JupyROOT 6.26/04
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'belle2', 'belle2_modern', 'belle2_serif', 'belle2_wg1', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
def Draw(option=None,loc=None,var_name=None, var_unit=None,file='file', tree='tree', figname='name',base_filter=None, true_filter=None, false_filter=None, add_t_filter=None, add_f_filter=None, bins=None):
    tree=tree
    #base_filter = '(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55) ' 
    var_name=var_name
    #var_name["D0_M"]="M(D^0)"

    var_unit=var_unit
    #var_unit["D0_M"]="GeV/c^2"

    var=list(var_name.keys())
    print(var)
     
    if loc=='home':
        file = "/home/jykim/storage/nas" + file[27:]
    elif loc=='lab':
        file = "/home/jykim/nas" + file[21:]        
    else:
        file = file
        
        
    base_filter = base_filter
    true_filter = base_filter + true_filter
    false_filter = base_filter + false_filter
    
    if add_t_filter != None:
        true_filter = true_filter + add_t_filter
    elif add_f_filter != None:
        false_filter = false_filter + add_f_filter
    else:
        pass
        
        
    '''
    if vector == 'omega':
        base_filter += ' && ( abs(Omega_M- 0.78265) < 0.015 )'
    elif vector == 'phi':
        base_filter += ' && ( abs(Phi_M- 1.0195) < 0.011 )'
    elif vector == 'rho':
        base_filter += ' && ( abs(Rho_M- 0.77526) < 0.150 )'
    elif vector == 'antiKstar':
        base_filter += ' && ( abs(antiKstar_M- 0.89555) < 0.06 )'
    '''

    '''
    if vector == 'omega':
        plot_title = r"$\omega$ mode"
    elif vector == 'phi':
        plot_title = r"$\phi$ mode"
    elif vector == 'rho':
        plot_title = r"$\rho^0$ mode"
    elif vector == 'antiKstar':
        plot_title = r"$\bar{K}^{*0}$ mode"
    '''


    ROOT_df_start = ROOT.RDataFrame(tree, file)
    # Compute new variable

        

    
    ROOT_df       = ROOT_df_start.Filter(base_filter)
    ROOT_df_true  = ROOT_df_start.Filter(true_filter)                        
    ROOT_df_false = ROOT_df_start.Filter(false_filter)

    col_dict       = ROOT_df.AsNumpy(var)    
    col_dict_true  = ROOT_df_true.AsNumpy(var)
    col_dict_false = ROOT_df_false.AsNumpy(var)

    pd_df       = pd.DataFrame(col_dict)
    pd_df_true  = pd.DataFrame(col_dict_true)
    pd_df_false = pd.DataFrame(col_dict_false)  

    pd_df['class'] = 'all'
    pd_df_true['class'] = 'true'
    pd_df_false['class'] = 'false' 
    
    print('# of false is ' + str(pd_df_false.shape[0]) )

    px = 1/plt.rcParams['figure.dpi']
    plt.figure(figsize=(576*px, 396*px))
    
    for i in var:
        

        #plt.hist(pd_df[i], label=r'all',bins=bins,  histtype='step') 
        #plt.hist(pd_df_true[i], label=r'true',bins=bins,  histtype='step') 
        plt.hist(pd_df_false[i], label=r'bkg',bins=bins,  histtype='step') 
        

        #bp.hist(pd_df[i], label=r'all',bins=bins) 
        #bp.hist(pd_df_true[i], label=r'true',bins=bins) 
        #bp.hist(pd_df_false[i], label=r'false',bins=bins) 
        
        ax = plt.gca()
        ax.set_xlim(pd_df[i].min(), pd_df[i].max())
        
        if i in var:
            if var_unit[i]=="":
                xlabel = "$" + var_name[i] + "$"
            else:    
                xlabel = "$" + var_name[i] + "$ $[" + var_unit[i] + "]$"
            ax.set_xlabel(xlabel)            
            x_axis = ax.get_xbound()
            width = (x_axis[1] - x_axis[0])/bins  
            print("one bin's size is " + str(width))
            ax.set_ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + var_unit[i] + ' )$')                                      
        else:
            xlabel = i
            ax.set_xlabel(xlabel)            
            x_axis = ax.get_xbound()
            width = (x_axis[1] - x_axis[0])/bins
            ax.set_ylabel('Entries'+' /' + '$(' + ' '  + "{0:.4f}".format(width).rstrip('0').rstrip('.') + ' )$')
            #ax.set_ylabel('Entries')                
        
        #bp.stacked(pd_merge_df, col=i, by='class', bins=100, color = sns.cubehelix_palette(8, start=1.5, rot=1.5, dark=0.3, light=.8, reverse=True))
        plt.legend()
        plt.title(plot_title)
        #plt.legend(bbox_to_anchor=(1,1))
        #bp.labels(i, "Entries")

      
        #ax2 = ax1.twinx()
        
        #ax2.hist(cc_pd_df_true[i], label=r'signal', bins=bins, color='tab:blue', histtype='step')

        #ax2.tick_params(axis='y', labelcolor='tab:blue')
        #bp.hist(pd_merge_df_false[i], label=r'others', bins=bins)  
        
        #bp.stacked(pd_df, col=i,by='label', bins=140)        
        #bp.stacked(df_bkg_real_pi0,col='D0_M', label=r'from real_pi0', bins=140, color="b")
        #bp.stacked(df_bkg_fake_pi0[i], label=r'from fake_pi0', bins=140, color="g")
        
        
        

        #save_dir = "/home/belle2/jaeyoung/plots/" + vector  + "/Dstarp/" + figname + i + ".png"
        #bp.save(save_dir)
        plt.show()
        plt.clf() 

    
    '''
    if vector == 'omega':
    
        corr_D0M_dalitz = lambda g: g['D0_M'].corr(g['cos_dalitz_pip'])
        grouped = pd_df.groupby('Dstarp_isSignal')
    
        print(pd.DataFrame(grouped.apply(corr_D0M_dalitz)))
        
        corr_D0M_dalitz = lambda g: g['D0_M'].corr(g['cos_dalitz_pip'])
        grouped = pd_df.groupby('D0_isSignal')
    
        print(pd.DataFrame(grouped.apply(corr_D0M_dalitz)))      
    '''

# %% [markdown]
# # D to Pip Pim Pi0

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
#var_name["Dstarp_delM"]="\Delta M"
#var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
#var_unit["Dstarp_delM"]="GeV/c^2"
#var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
#plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree='Dstar'
base_filter=''
true_filter=''
false_filter=''

Draw(option='on',var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M']
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# /tmp/ipykernel_14736/602257110.py in <module>
#      21 false_filter=''
#      22
# ---> 23 Draw(option='on',var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
#
# /tmp/ipykernel_14736/659664423.py in Draw(option, loc, var_name, var_unit, file, tree, figname, base_filter, true_filter, false_filter, add_t_filter, add_f_filter, bins)
#      64     ROOT_df_false = ROOT_df_start.Filter(false_filter)
#      65
# ---> 66     col_dict       = ROOT_df.AsNumpy(var)
#      67     col_dict_true  = ROOT_df_true.AsNumpy(var)
#      68     col_dict_false = ROOT_df_false.AsNumpy(var)
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      81     py_arrays = {}
#      82     for column in columns:
# ---> 83         cpp_reference = result_ptrs[column].GetValue()
#      84         if hasattr(cpp_reference, "__array_interface__"):
#      85             tmp = numpy.asarray(cpp_reference) # This adopts the memory of the C++ object.
#
# runtime_error: const vector<double>& ROOT::RDF::RResultPtr<vector<double> >::GetValue() =>
#     runtime_error:
# An error occurred during just-in-time compilation in RLoopManager::Run. The lines above might indicate the cause of the crash
# All RDF objects that have not run their event loop yet should be considered in an invalid state.
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/input_line_9:15:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/etc/dictpch/allHeaders.h:561:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RCsvDS.hxx:14:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDataFrame.hxx:20:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RInterface.hxx:18:
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/InterfaceUtils.hxx:276:4: error: static_assert failed due to requirement 'std::is_convertible<void, bool>::value' "filter expression returns a type that is not convertible to bool"
#    static_assert(std::is_convertible<FilterRet_t, bool>::value,
#    ^             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/InterfaceUtils.hxx:389:17: note: in instantiation of function template specialization 'ROOT::Internal::RDF::CheckFilter<__rdf::(lambda at input_line_74:2:16)>' requested here
#    RDFInternal::CheckFilter(f);
#                 ^
# input_line_79:2:23: note: in instantiation of function template specialization 'ROOT::Internal::RDF::JitFilterHelper<__rdf::(lambda at input_line_74:2:16) &, ROOT::Detail::RDF::RNodeBase>' requested here
#  ROOT::Internal::RDF::JitFilterHelper(__rdf::lambda0, new const char*[0]{}, 0, "", reinterpret_cast<std::weak_ptr<ROOT::Detail::RDF::RJittedFilter>*>(0xf285d20), reinterpret_cast<std::shared_ptr<ROOT::Detail::RDF::RNodeBase>*>(0x8c96400),reinterpret_cast<ROOT::Internal::RDF::RBookedDefines*>(0xf2888e0));
#                       ^
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/input_line_9:15:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/etc/dictpch/allHeaders.h:561:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RCsvDS.hxx:14:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDataFrame.hxx:20:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RInterface.hxx:18:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/InterfaceUtils.hxx:18:
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RFilter.hxx:108:14: error: cannot initialize return object of type 'bool' with an rvalue of type 'void'
#       return fFilter(fValues[slot][S]->template Get<ColTypes>(entry)...);
#              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RFilter.hxx:92:27: note: in instantiation of function template specialization 'ROOT::Detail::RDF::RFilter<__rdf::(lambda at input_line_74:2:16), ROOT::Detail::RDF::RNodeBase>::CheckFilterHelper<>' requested here
#             auto passed = CheckFilterHelper(slot, entry, ColumnTypes_t{}, TypeInd_t{});
#                           ^
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RFilter.hxx:67:4: note: in instantiation of member function 'ROOT::Detail::RDF::RFilter<__rdf::(lambda at input_line_74:2:16), ROOT::Detail::RDF::RNodeBase>::CheckFilters' requested here
#    RFilter(FilterF f, const ColumnNames_t &columns, std::shared_ptr<PrevDataFrame> pd,
#    ^
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/InterfaceUtils.hxx:398:40: note: in instantiation of member function 'ROOT::Detail::RDF::RFilter<__rdf::(lambda at input_line_74:2:16), ROOT::Detail::RDF::RNodeBase>::RFilter' requested here

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
#var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
#var_unit["cos_dalitz_pip"]=""
var_unit["D0_cosHel_0"]=""

bins=100
#plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6.root'
tree='rho'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Rho_M- 0.77526) < 0.150 ) && (Dstarp_CMS_p>2.72) && (abs(Dstarp_Q-0.00593)<0.0006)'
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'D0_cosHel_0']
# # of false is 8959
# one bin's size is 0.003985631465911865
# one bin's size is 1.1998414993286133e-05
# one bin's size is 0.0199992411973233
# input_line_92:10:7: warning: ignoring return value of function declared with 'nodiscard' attribute [-Wunused-result]
#       ((const vector<double>*)obj)->empty();
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
#plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6.root'
tree='omega'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && \
Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006'
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'cos_dalitz_pip']
# # of false is 245
# one bin's size is 0.003968628644943237
# one bin's size is 1.1899471282958984e-05
# one bin's size is 0.019821125426331253

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
#plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree='omega'
base_filter=''

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)

# %% [markdown]
# # D to Pip Pim 2 Pi0

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0 \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippim2pi0/ntuple/recon_mdst_e6.root'
tree='omega'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && \
Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006'
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'cos_dalitz_pip']
# # of false is 472
# one bin's size is 0.003969055414199829
# one bin's size is 1.1878013610839844e-05
# one bin's size is 0.01996187133423356

# %% [markdown]
# # D to omega Pi0

# %%
var_name={}
var_name["D0_M"]="M(D^0)"3d
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
plot_title=r"$\rho^0$ mode"
plot_title=r"$D^0 \rightarrow \omega \pi^0$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2omegapi0/ntuple/recon_mdst_e6.root'
tree='omega'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && \
  Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006'
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'cos_dalitz_pip']
# # of false is 10620
# one bin's size is 0.003997937440872192
# one bin's size is 1.1993646621704101e-05
# one bin's size is 0.019829354445993704

# %% [markdown]
# # D to omega eta

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
plot_title=r"$D^0 \rightarrow \omega \eta$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2omegaeta/ntuple/recon_mdst_e6.root'
tree='omega'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && \
  Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006 '
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'cos_dalitz_pip']
# # of false is 1369
# one bin's size is 0.0038916945457458498
# one bin's size is 1.1990070343017578e-05
# one bin's size is 0.019850821351211908

# %% [markdown]
# # D to Pip Pim Pi0 eta

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
var_name["Dstarp_delM"]="\Delta M"
var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
var_unit["Dstarp_delM"]="GeV/c^2"
var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0 \eta$"

file='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0eta/ntuple/recon_mdst_e6.root'
tree='omega'
base_filter='(D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && \
  Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006 '
true_filter='&& (Dstarp_isSignal==1)'
false_filter='&& (Dstarp_isSignal!=1)'

Draw(var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M', 'Dstarp_delM', 'cos_dalitz_pip']
# # of false is 156
# one bin's size is 0.0036314547061920164
# one bin's size is 1.1831521987915039e-05
# one bin's size is 0.019790249831849044
# input_line_84:10:7: warning: ignoring return value of function declared with 'nodiscard' attribute [-Wunused-result]
#       ((const vector<double>*)obj)->empty();
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
import proplot as pplt
import numpy as np

# Sample data
state = np.random.RandomState(51423)
data = 10 + state.normal(0, 1, size=(33, 33)).cumsum(axis=0).cumsum(axis=1)

# Figure
fig, axs = pplt.subplots([[1, 1, 2, 2], [0, 3, 3, 0]], ref=3, refwidth=2.3)
axs.format(yformatter='none', suptitle='Discrete vs. smooth colormap levels')

# Pcolor
axs[0].pcolor(data, cmap='viridis', colorbar='l')
axs[0].set_title('Pcolor plot\ndiscrete=True (default)')
axs[1].pcolor(data, discrete=False, cmap='viridis', colorbar='r')
axs[1].set_title('Pcolor plot\ndiscrete=False')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1887/2390051995.py in <module>
#       7
#       8 # Figure
# ----> 9 fig, axs = pplt.subplots([[1, 1, 2, 2], [0, 3, 3, 0]], ref=3, refwidth=2.3)
#      10 axs.format(yformatter='none', suptitle='Discrete vs. smooth colormap levels')
#      11
#
# ~/.local/lib/python3.8/site-packages/proplot/ui.py in subplots(*args, **kwargs)
#     190     # Initialize
#     191     fig = figure(rc_kw=rc_kw, **kwargs)
# --> 192     axs = fig.add_subplots(*args, **kwsubs)
#     193     axs.format(rc_kw=rc_kw, **kwformat)
#     194     return fig, axs
#
# ~/.local/lib/python3.8/site-packages/proplot/figure.py in add_subplots(self, array, ncols, nrows, order, proj, projection, proj_kw, projection_kw, basemap, **kwargs)
#    1360             ss = gs[y0:y1 + 1, x0:x1 + 1]
#    1361             kw = {**kwargs, **axes_kw[num], 'number': num}
# -> 1362             axs[idx] = self.add_subplot(ss, **kw)
#    1363
#    1364         self.format(**figure_kw)
#
# ~/.local/lib/python3.8/site-packages/proplot/figure.py in add_subplot(self, number, *args, **kwargs)
#    1246         self._subplot_counter += 1  # unique label for each subplot
#    1247         kwargs.setdefault('label', f'subplot_{self._subplot_counter}')
# -> 1248         ax = super().add_subplot(ss, _subplot_spec=ss, **kwargs)
#    1249         if number:
#    1250             self._subplot_dict[number] = ax
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/cartesian.py in __init__(self, *args, **kwargs)
#     336         self._xaxis_isdefault_rotation = True  # whether to auto rotate the axis
#     337         self._yaxis_isdefault_rotation = True
# --> 338         super().__init__(*args, **kwargs)
#     339
#     340         # Apply default formatter
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/plot.py in __init__(self, *args, **kwargs)
#    1258         proplot.axes.GeoAxes
#    1259         """
# -> 1260         super().__init__(*args, **kwargs)
#    1261
#    1262     def _plot_native(self, name, *args, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/base.py in __init__(self, *args, **kwargs)
#     781             self.set_subplotspec(ss)
#     782         if autoshare:
# --> 783             self._auto_share()
#     784
#     785         # Default formatting
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/base.py in _auto_share(self)
#    1775         parent, *children = self._get_share_axes('y')
#    1776         for child in children:
# -> 1777             child._sharey_setup(parent)
#    1778         # Global sharing, use the reference subplot because why not
#    1779         ref = self.figure._subplot_dict.get(self.figure._refnum, None)
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/cartesian.py in _sharey_setup(self, sharey, labels, limits)
#     603             self._sharey = sharey
#     604         if level > 1 and limits:
# --> 605             self._sharey_limits(sharey)
#     606
#     607     def _update_formatter(
#
# ~/.local/lib/python3.8/site-packages/proplot/axes/cartesian.py in _sharey_limits(self, sharey)
#     546             if ax1.get_autoscaley_on() and not ax2.get_autoscaley_on():
#     547                 ax1.set_ylim(ax2.get_ylim())
# --> 548         self._shared_y_axes.join(self, sharey)  # share limit/scale changes
#     549         if sharey.yaxis.isDefault_majloc and not self.yaxis.isDefault_majloc:
#     550             sharey.yaxis.set_major_locator(self.yaxis.get_major_locator())
#
# AttributeError: 'CartesianAxesSubplot' object has no attribute '_shared_y_axes'
# Figure(nrows=2, ncols=4, refwidth=2.3)

# %% [markdown]
# # ETC

# %%
# def get_data(file='file', figname='name', tree='tree', base_filter=None,variables=None):
    
#     tree=tree
#     f = file
#     base_filter  = base_filter    
    
#     ROOT_df_start = ROOT.RDataFrame(tree, f)  
#     col_dict  = ROOT_df_start.AsNumpy(variables)
    
#     if base_filter !=None:
#         ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)                            
#         col_dict  = ROOT_df_filtered.AsNumpy(variables)
    
#     pd_df  = pd.DataFrame(col_dict)
    
    
#     return pd_df

# %%
def compute(row):
    
    E = row['pip_E'] + row['pim_E']
    px = row['pip_px'] + row['pim_px']
    py = row['pip_py'] + row['pim_py']
    pz = row['pip_pz'] + row['pim_pz']
    
    InvM = math.sqrt(E*E - (px*px + py*py + pz*pz))
    
    return InvM

# %%
file = '/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
file = '/home/jykim/nas/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree = 'Dstar'
base_filter = '()'
variables=['pip_E','pim_E','pip_px','pim_px','pip_py','pim_py','pip_pz','pim_pz']

pd_df = get_data(file=file, tree=tree,variables=variables )

pd_df['pippim'] = pd_df.apply(lambda row: compute(row), axis=1)

# %%
plt.hist(pd_df['pippim'], label=r'bkg',bins=100,  histtype='step') 

plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(\pi^+\pi^-)$"
ax.set_xlabel(xlabel)
ax.set_ylabel('Entries')

plt.axvline(x=0.92526,  color='red', linestyle='dotted')
plt.axvline(x=0.62526,  color='red', linestyle='dotted')

# %%
def compute_2(row):
    
    E = row['pip_E'] + row['pi0_E']
    px = row['pip_px'] + row['pi0_px']
    py = row['pip_py'] + row['pi0_py']
    pz = row['pip_pz'] + row['pi0_pz']
    
    InvM = math.sqrt(E*E - (px*px + py*py + pz*pz))
    
    return InvM

# %%
file = '/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree = 'Dstar'
base_filter = '()'
variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']

pd_df = get_data(file=file, tree=tree,variables=variables )

pd_df['pippi0'] = pd_df.apply(lambda row: compute_2(row), axis=1)

# %%
plt.hist(pd_df['pippi0'], label=r'bkg',bins=100,  histtype='step') 

plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(\pi^+\pi^0)$"
ax.set_xlabel(xlabel)
ax.set_ylabel('Entries')
# Out:
# Text(0, 0.5, 'Entries')

# %%
def compute_3(row):
    
    E = row['pim_E'] + row['pi0_E']
    px = row['pim_px'] + row['pi0_px']
    py = row['pim_py'] + row['pi0_py']
    pz = row['pim_pz'] + row['pi0_pz']
    
    InvM = math.sqrt(E*E - (px*px + py*py + pz*pz))
    
    return InvM

# %%
file = '/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree = 'Dstar'
base_filter = '()'
variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']

pd_df = get_data(file=file, tree=tree,variables=variables )

pd_df['pimpi0'] = pd_df.apply(lambda row: compute_3(row), axis=1)

# %%
file = '/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6_gen.root'
tree = 'Dstar'
base_filter = '()'
variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']

pd_df = get_data(file=file, tree=tree,variables=variables )

pd_df['pippi0'] = pd_df.apply(lambda row: compute_3(row), axis=1)
# Out:
# Text(0, 0.5, 'Entries')

# %%
plt.hist(pd_df['pimpi0'], label=r'bkg',bins=100,  histtype='step') 

plot_title=r"$D^0 \rightarrow \pi^+ \pi^- \pi^0$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(\pi^-\pi^0)$"
ax.set_xlabel(xlabel)
ax.set_ylabel('Entries')

# %%
def compute_4(row):
    
    E = row['km_E'] + row['pip_E']
    px = row['km_px'] + row['pip_px']
    py = row['km_py'] + row['pip_py']
    pz = row['km_pz'] + row['pip_pz']
    
    InvM = math.sqrt(E*E - (px*px + py*py + pz*pz))
    
    return InvM

# %%
file = '/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/D2kmpippi0/ntuple/recon_mdst_e6_gen.root'
tree = 'Dstar'
base_filter = '()'
variables=['km_E','pip_E','pi0_E','km_px','pip_px','pi0_px','km_py','pip_py','pi0_py','km_pz','pip_pz','pi0_pz']

pd_df = get_data(file=file, tree=tree,variables=variables )
pd_df

pd_df['kmpip'] = pd_df.apply(lambda row: compute_4(row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_186168/3969785350.py in <module>
#       7 pd_df
#       8
# ----> 9 pd_df['kmpip'] = pd_df.apply(lambda row: compute_4(row), axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'apply'

# %%
pd_df.describe()
# Out:
#                km_E         pip_E         pi0_E         km_px        pip_px  \
# count  1.013469e+06  1.013469e+06  1.013469e+06  1.013469e+06  1.013469e+06
# mean   1.520410e+00  9.947091e-01  9.319040e-01  6.173797e-02  4.036635e-02
# std    7.633399e-01  7.320945e-01  7.092343e-01  8.496642e-01  6.454707e-01
# min    4.937252e-01  1.395901e-01  1.349864e-01 -3.992048e+00 -3.548537e+00
# 25%    9.196051e-01  4.358746e-01  3.992524e-01 -4.328563e-01 -2.631311e-01
# 50%    1.348511e+00  7.698474e-01  7.034124e-01  4.613004e-02  2.257739e-02
# 75%    1.955163e+00  1.368317e+00  1.273323e+00  5.434125e-01  3.284163e-01
# max    5.922090e+00  5.103679e+00  5.243852e+00  4.547974e+00  3.914903e+00
#
#              pi0_px         km_py        pip_py        pi0_py         km_pz  \
# count  1.013469e+06  1.013469e+06  1.013469e+06  1.013469e+06  1.013469e+06
# mean   3.909051e-02  1.965022e-03  5.490744e-04  1.979442e-04  4.073280e-01
# std    6.109240e-01  8.487881e-01  6.435787e-01  6.112169e-01  1.019076e+00
# min   -3.602034e+00 -4.064255e+00 -3.854120e+00 -3.718095e+00 -3.180547e+00
# 25%   -2.396727e-01 -4.857368e-01 -2.947440e-01 -2.699271e-01 -2.492051e-01
# 50%    2.067991e-02  1.676118e-03  3.848089e-04  3.888495e-04  2.829406e-01
# 75%    3.020218e-01  4.898798e-01  2.960292e-01  2.708200e-01  9.698400e-01
# max    4.000887e+00  4.198672e+00  3.848886e+00  3.722734e+00  5.834254e+00
#
#              pip_pz        pi0_pz         kmpip
# count  1.013469e+06  1.013469e+06  1.013469e+06
# mean   2.664729e-01  2.491953e-01  1.218365e+00
# std    7.761869e-01  7.367494e-01  3.558845e-01
# min   -3.009475e+00 -2.871233e+00  6.332627e-01
# 25%   -1.491822e-01 -1.366551e-01  8.970488e-01
# 50%    1.404042e-01  1.284762e-01  1.191014e+00
# 75%    5.718807e-01  5.255739e-01  1.579574e+00
# max    4.920674e+00  5.020322e+00  1.729747e+00

# %%
plt.hist(pd_df['kmpip'], label=r'bkg',bins=100,  histtype='step') 

plot_title=r"$D^0 \rightarrow K^- \pi^+ \pi^0$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(K^-\pi^+)$"
ax.set_xlabel(xlabel)
ax.set_ylabel('Entries')

plt.axvline(x=0.95555,  color='red', linestyle='dotted')
plt.axvline(x=0.83555,  color='red', linestyle='dotted')

# %%
var_name={}
var_name["D0_M"]="M(D^0)"
#var_name["Pi0_Prob"]="Pi0_Prob"
#var_name["Dstarp_delM"]="\Delta M"
#var_name["cos_dalitz_pip"]=r"\cos\theta_{D}"
#var_name["D0_cosHel_0"]=r"\cos\theta_{H}"

var_unit={}
var_unit["D0_M"]="GeV/c^2"
#var_unit["Pi0_Prob"]="Pi0_Prob"
#var_unit["Dstarp_delM"]="GeV/c^2"
#var_unit["cos_dalitz_pip"]=""
#var_unit["D0_cosHel_0"]=""

bins=100
#plot_title=r"$\rho^0$ mode"
plot_title=r"$test$"

file='/group/belle/users/jaeyoung/storage/01_recon/train/recon_output.root'

file='/group/belle/users/jaeyoung/storage/01_recon/merge_generic_bkg/charged//train_v1_yes_signal_charged_recon_output_02.root'
tree='phi'
base_filter=''
true_filter=''
false_filter=''

Draw(option='on',var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
# Out:
# ['D0_M']
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# /tmp/ipykernel_286249/4194885463.py in <module>
#      25 false_filter=''
#      26
# ---> 27 Draw(option='on',var_name=var_name, var_unit=var_unit, file=file, tree=tree, base_filter=base_filter, true_filter=true_filter, false_filter=false_filter,bins=bins)
#
# /tmp/ipykernel_286249/1946796281.py in Draw(option, loc, var_name, var_unit, file, tree, figname, base_filter, true_filter, false_filter, add_t_filter, add_f_filter, bins)
#      64     ROOT_df_false = ROOT_df_start.Filter(false_filter)
#      65
# ---> 66     col_dict       = ROOT_df.AsNumpy(var)
#      67     col_dict_true  = ROOT_df_true.AsNumpy(var)
#      68     col_dict_false = ROOT_df_false.AsNumpy(var)
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      81     py_arrays = {}
#      82     for column in columns:
# ---> 83         cpp_reference = result_ptrs[column].GetValue()
#      84         if hasattr(cpp_reference, "__array_interface__"):
#      85             tmp = numpy.asarray(cpp_reference) # This adopts the memory of the C++ object.
#
# runtime_error: const vector<double>& ROOT::RDF::RResultPtr<vector<double> >::GetValue() =>
#     runtime_error:
# An error occurred during just-in-time compilation in RLoopManager::Run. The lines above might indicate the cause of the crash
# All RDF objects that have not run their event loop yet should be considered in an invalid state.
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/input_line_9:15:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/etc/dictpch/allHeaders.h:561:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RCsvDS.hxx:14:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDataFrame.hxx:20:
# In file included from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/RInterface.hxx:18:
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/build/Linux_x86_64/common/root/include/ROOT/RDF/InterfaceUtils.hxx:388:42: error: no member named 'list_size' in 'ROOT::TypeTraits::TypeList<>'
#    constexpr auto nColumns = ColTypes_t::list_size;
#                              ~~~~~~~~~~~~^
# input_line_174:2:23: note: in instantiation of function template specialization 'ROOT::Internal::RDF::JitFilterHelper<__rdf::(lambda at input_line_140:2:16) &, ROOT::Detail::RDF::RNodeBase>' requested here
#  ROOT::Internal::RDF::JitFilterHelper(__rdf::lambda0, new const char*[0]{}, 0, "", reinterpret_cast<std::weak_ptr<ROOT::Detail::RDF::RJittedFilter>*>(0x1c027290), reinterpret_cast<std::shared_ptr<ROOT::Detail::RDF::RNodeBase>*>(0x1bf113a0),reinterpret_cast<ROOT::Internal::RDF::RBookedDefines*>(0x1e1b6620));
#                       ^

# %%
##############################################

def get_data(file='file', figname='name', tree='tree', base_filter=None,variables=None):
    
    tree=tree
    f = file
    base_filter  = base_filter    
    
    ROOT_df_start = ROOT.RDataFrame(tree, f)  
    col_dict  = ROOT_df_start.AsNumpy(variables)
    
    if base_filter !=None:
        ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)                            
        col_dict  = ROOT_df_filtered.AsNumpy(variables)
    
    pd_df  = pd.DataFrame(col_dict)
    
    return pd_df

# %%
file='/media/jykim/ssd_T5/storage/01_recon/antiKstar/massveto_E_0_5_signalMC_recon_mdst_antiKstar.root'
file='/media/jykim/ssd_T5/storage/01_recon/antiKstar/massveto_signalMC_recon_mdst_antiKstar.root'

base_filter = 'Dstarp_isSignal==1'

tree = 'antiKstar'

variables=['ROE_Pi0_InvM','ROE_Pi0_InvM_50MeV','ROE_Pi0_InvM_75MeV','ROE_Pi0_InvM_100MeV','ROE_Pi0_InvM_125MeV','ROE_Pi0_InvM_150MeV']
variables+= ['ROE_Eta_InvM','ROE_Eta_InvM_50MeV','ROE_Eta_InvM_75MeV','ROE_Eta_InvM_100MeV','ROE_Eta_InvM_125MeV','ROE_Eta_InvM_150MeV','ROE_Eta_InvM_175MeV','ROE_Eta_InvM_200MeV']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

# %%
plt.hist(pd_df[(pd_df['ROE_Pi0_InvM']<0.16) & (pd_df['ROE_Pi0_InvM']>0.1)].ROE_Pi0_InvM, label=r'base',bins=100,  histtype='step')

plt.hist(pd_df[(pd_df['ROE_Pi0_InvM_50MeV']<0.16) & (pd_df['ROE_Pi0_InvM_50MeV']>0.1) ].ROE_Pi0_InvM_50MeV, label=r'$E_{\gamma_{roe}}>50\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Pi0_InvM_75MeV']<0.16) & (pd_df['ROE_Pi0_InvM_75MeV']>0.1)].ROE_Pi0_InvM_75MeV, label=r'$E_{\gamma_{roe}}>75\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Pi0_InvM_100MeV']<0.16) & (pd_df['ROE_Pi0_InvM_100MeV']>0.1)].ROE_Pi0_InvM_100MeV, label=r'$E_{\gamma_{roe}}>100\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Pi0_InvM_125MeV']<0.16) & (pd_df['ROE_Pi0_InvM_125MeV']>0.1)].ROE_Pi0_InvM_125MeV, label=r'$E_{\gamma_{roe}}>125\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Pi0_InvM_150MeV']<0.16) & (pd_df['ROE_Pi0_InvM_150MeV']>0.1)].ROE_Pi0_InvM_150MeV, label=r'$E_{\gamma_{roe}}>150\mathrm{MeV}$',bins=100,histtype='step')

plot_title = r'1M true Signal MC$(D^0 \rightarrow \bar{K}^{*0} \gamma)$'
xlabel = r'$M(\gamma_h \gamma_{roe}) \; [\mathrm{GeV}]$'
ax = plt.gca()
ax.set_xlim(0.10,0.16)
ax.set_xlabel(xlabel)
plt.title(plot_title)

plt.legend(loc='upper left')

# %%
plt.hist(pd_df[(pd_df['ROE_Eta_InvM']<0.7) & (pd_df['ROE_Eta_InvM']>0.4)].ROE_Eta_InvM, label=r'base',bins=100,  histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_50MeV']<0.7) & (pd_df['ROE_Eta_InvM_50MeV']>0.4) ].ROE_Eta_InvM_50MeV, label=r'$E_{\gamma_{roe}}>50\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_75MeV']<0.7) & (pd_df['ROE_Eta_InvM_75MeV']>0.4)].ROE_Eta_InvM_75MeV, label=r'$E_{\gamma_{roe}}>75\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_100MeV']<0.7) & (pd_df['ROE_Eta_InvM_100MeV']>0.4)].ROE_Eta_InvM_100MeV, label=r'$E_{\gamma_{roe}}>100\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_125MeV']<0.7) & (pd_df['ROE_Eta_InvM_125MeV']>0.4)].ROE_Eta_InvM_125MeV, label=r'$E_{\gamma_{roe}}>125\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_150MeV']<0.7) & (pd_df['ROE_Eta_InvM_150MeV']>0.4)].ROE_Eta_InvM_150MeV, label=r'$E_{\gamma_{roe}}>150\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_175MeV']<0.7) & (pd_df['ROE_Eta_InvM_175MeV']>0.4)].ROE_Eta_InvM_175MeV, label=r'$E_{\gamma_{roe}}>175\mathrm{MeV}$',bins=100,histtype='step')

plt.hist(pd_df[(pd_df['ROE_Eta_InvM_200MeV']<0.7) & (pd_df['ROE_Eta_InvM_200MeV']>0.4)].ROE_Eta_InvM_200MeV, label=r'$E_{\gamma_{roe}}>200\mathrm{MeV}$',bins=100,histtype='step')


plot_title = r'1M true Signal MC$(D^0 \rightarrow \bar{K}^{*0} \gamma)$'
xlabel = r'$M(\gamma_h \gamma_{roe}) \; [\mathrm{GeV}]$'
ax = plt.gca()
ax.set_xlim(0.40,0.7)
ax.set_xlabel(xlabel)
plt.title(plot_title)

plt.legend(loc='upper right')

# %%
Filter = {}
Filter['rho']= ' gamma_E>0.3 && gamma_clusterSecondMoment<=1.5 && (D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Rho_M- 0.77526) < 0.150 )&& Dstarp_CMS_p>2.72 && abs(Dstarp_Q-0.00593)<0.0006'
Filter['omega'] = 'gamma_E>0.3 && gamma_clusterSecondMoment<=1.5 && (D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Omega_M- 0.78265) < 0.015 ) && Dstarp_CMS_p>2.7 && abs(Dstarp_Q-0.00593)<0.0006 '
Filter['phi'] = 'gamma_E>0.3 && gamma_clusterSecondMoment<=1.5 && (D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(Phi_M- 1.0195) < 0.011 ) && Dstarp_CMS_p>2.42 && abs(Dstarp_Q-0.00593)<0.0006'
Filter['antiKstar']='gamma_E>0.3 && gamma_clusterSecondMoment<=1.5 && (D0_M>1.665 && D0_M<2.065) && (gamma_E>0.55)  && ( abs(antiKstar_M- 0.89555) < 0.06 )&& Dstarp_CMS_p>2.17 && abs(Dstarp_Q-0.00593)<0.0006'

# %%
file='/group/belle/users/jaeyoung/storage/01_recon/phi/pid_0_5_signalMC_recon_mdst_phi.root'
base_filter='Dstarp_isSignal==1'
tree='phi'
variables=['Phi_InvM']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
plt.hist(pd_df['Phi_InvM'], label=r'MC matched',bins=100,  histtype='step') 

ax = plt.gca()
ax.set_xlim(0.9995,1.0395)   
xlabel = r'$M(\phi)$'
plot_title = r'1M Signal MC$(D^0 \rightarrow \phi \gamma)$'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')
# Out:
# input_line_79:10:7: warning: ignoring return value of function declared with 'nodiscard' attribute [-Wunused-result]
#       ((const vector<double>*)obj)->empty();
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
file='/home/belle2/jaeyoung/workspace/06_MVA/my_pi0etaveto/train_files/pi0veto_train.root'
file='/media/jykim/ssd_T5/storage/workspace/06_MVA/my_pi0etaveto/files_train/pi0veto_train.root'



#file='/group/belle/users/jaeyoung/storage/pi0etaveto/frac_0_3/merged_frac_0_3/pi0etaveto_all_generic_recon_output.root'
file2='/group/belle/users/jaeyoung/storage/pi0etaveto/signal/frac_0_5_a/half_1M_0_recon_mdst_all.root'
file2='/media/jykim/ssd_T5/storage/pi0etaveto/signal/frac_0_5_a/half_1M_0_recon_mdst_all.root'



#base_filter='isSignal==1 && M<0.4'
#base_filter2='isSignal!=1 && M<0.4'
base_filter='isSignal==1'
base_filter2='isSignal!=1 && daughter__bo0__cmgenMotherPDG__bc==421'
base_filter2='isSignal!=1'

tree='pi0'
variables=['M','cosHelicityAngleMomentum','daughter__bo1__cmE__bc','daughter__bo1__cmclusterTheta__bc','daughter__bo1__cmclusterNHits__bc',\
           'daughter__bo1__cmclusterE9E21__bc','daughter__bo1__cmminC2TDist__bc','daughter__bo1__cmclusterZernikeMVA__bc','daughter__bo0__cmE__bc','daughter__bo0__cmgenMotherID__bc','hardPhotonECMS']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
pd_df1 = get_data(file=file2, tree=tree,variables=variables ,base_filter=base_filter2)

# %%
plot_bins = np.arange(-1, 1, 0.05)
len(plot_bins)
# Out:
# 40

# %%
x=pd_df1[(pd_df1['daughter__bo0__cmE__bc']<1) & (pd_df1['daughter__bo1__cmE__bc']<1)]['daughter__bo0__cmE__bc']
y=pd_df1[(pd_df1['daughter__bo0__cmE__bc']<1) & (pd_df1['daughter__bo1__cmE__bc']<1)]['daughter__bo1__cmE__bc']


plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.jet)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

plot_title=r"$\mathrm{E}_{\gamma_1} , \mathrm{E}_{\gamma_2}$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$\mathrm{E}_{\gamma_1}$"
ylabel = r"$\mathrm{E}_{\gamma_2}$"
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax = plt.gca()
ax.set_xlim(0,) 
#ax.set_xlim(x.min(), x.max())
#ax.set_ylim(y.min(), y.max())

plt.colorbar()
plt.show()

# %%
x=pd_df[(pd_df['daughter__bo0__cmE__bc']<1) & (pd_df['daughter__bo1__cmE__bc']<1)]['daughter__bo0__cmE__bc']
y=pd_df[(pd_df['daughter__bo0__cmE__bc']<1) & (pd_df['daughter__bo1__cmE__bc']<1)]['daughter__bo1__cmE__bc']


plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.jet)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

plot_title=r"$\mathrm{E}_{\gamma_1} , \mathrm{E}_{\gamma_2}$"
plt.title(plot_title)
ax = plt.gca()
xlabel = r"$\mathrm{E}_{\gamma_1}$"
ylabel = r"$\mathrm{E}_{\gamma_2}$"
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax = plt.gca()
ax.set_xlim(0,) 
#ax.set_xlim(x.min(), x.max())
#ax.set_ylim(y.min(), y.max())

plt.colorbar()
plt.show()

# %%
#plt.hist(pd_df['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='step', density=False, hatch="//") 
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']<0.3]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like, $E_{\gamma_2}<300\mathrm{MeV}$',bins=plot_bins,  histtype='step', density=False, hatch="//") 
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']>0.3]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like, $E_{\gamma_2}>300\mathrm{MeV}$',bins=plot_bins,  histtype='step', density=False, hatch="//") 

# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
# plot_bins = [*range(-1,1,0.01)]
plot_bins = np.arange(-1, 1, 0.05)

plt.hist(pd_df['cosHelicityAngleMomentum'], label=r'$\gamma_1>300\mathrm{MeV}$',bins=plot_bins,  histtype='step', density=False, hatch="//") 
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']<0.3]['cosHelicityAngleMomentum'], label=r'$\gamma_1>300\mathrm{MeV},\gamma_2<300\mathrm{MeV}$',bins=plot_bins,  histtype='step', density=False, hatch="//") 
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']>0.3]['cosHelicityAngleMomentum'], label=r'$\gamma_1>300\mathrm{MeV},\gamma_2>300\mathrm{MeV}$',bins=plot_bins,  histtype='step', density=False, hatch="//") 

# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'true $\pi^0$ in generic 0.3$\mathrm{ab}^{-1}$'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['hardPhotonECMS']>0.7]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']<0.3]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']>0.3 ]['cosHelicityAngleMomentum'], label=r'$\gamma_1>300\mathrm{MeV},\gamma_2>300\mathrm{MeV}$',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'true $\pi^0$ in generic 0.3$\mathrm{ab}^{-1}$'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper left')

# %%
g1_E=pd_df[pd_df['daughter__bo1__cmE__bc']>0.3 ]['daughter__bo0__cmE__bc']
g2_E=pd_df[pd_df['daughter__bo1__cmE__bc']>0.3 ]['daughter__bo1__cmE__bc']

#df=pd.Dataframe(data = g2_E/g1_E)

# %%
def ratio(row):

    
    ratio = row['daughter__bo1__cmE__bc']/row['daughter__bo0__cmE__bc']
    
    return ratio

# %%
#variables=['km_E','pip_E','pi0_E','km_px','pip_px','pi0_px','km_py','pip_py','pi0_py','km_pz','pip_pz','pi0_pz']

df = pd_df[pd_df['daughter__bo1__cmE__bc']>0.3 ]


df['ratio'] = df.apply(lambda row: ratio(row), axis=1)
# Out:
# /tmp/ipykernel_3061/274785139.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ratio'] = df.apply(lambda row: ratio(row), axis=1)

# %%
plt.hist(df['ratio'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,1)   
xlabel = r'ratio'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(0,)  
plt.legend(loc='upper right')

# %%
plt.hist(df[df['ratio']<5]['ratio'], label=r'$\gamma_1>300\mathrm{MeV},\gamma_2>300\mathrm{MeV}$',bins=20,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,1)   
xlabel = r'$E_{\gamma_2}/E_{\gamma_1}$'
plot_title = r'true $\pi^0$ in generic 0.3$\mathrm{ab}^{-1}$'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(0,5) 
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']>0.3 ]['daughter__bo1__cmE__bc'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) & (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
#plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) & (pd_df['daughter__bo0__cmE__bc']<pd_df['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[(pd_df['daughter__bo1__cmE__bc']<0.3 ) & (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[ (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=plot_bins,  histtype='stepfilled', density=False, hatch="//") 
# plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
ax = plt.gca()
ax.set_xlim(-1,1)  
plt.legend(loc='upper right')

# %%
print(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) & (pd_df['daughter__bo0__cmE__bc']<pd_df['daughter__bo1__cmE__bc']) ].shape)
# Out:
# (2631638, 9)

# %%
print(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) & (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ].shape)
# Out:
# (2843335, 9)

# %%
print(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) ].shape)
# Out:
# (5475049, 9)

# %%
print(pd_df[(pd_df['daughter__bo1__cmE__bc']>0.3 ) ].shape)

# %%
#for i in variables

# %%
plt.hist(pd_df['daughter__bo1__cmclusterZernikeMVA__bc'], label=r'$\pi^0$ like',bins=100,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterZernikeMVA__bc'], label=r'not $\pi^0$ like',bins=100,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,0.8)   
xlabel = r"soft photon's clusterZernikeMVA"
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color`='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['M']<0.8].M, label=r'$\pi^0$ like',bins=100,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[pd_df1['M']<0.8].M, label=r'not $\pi^0$ like',bins=100,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,0.8)   
xlabel = r'$M(\gamma\gamma)$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color`='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[ (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ]['M'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[ (pd_df1['daughter__bo0__cmE__bc']>pd_df1['daughter__bo1__cmE__bc']) ]['M'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,0.4)   
xlabel = r'M'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[ (pd_df['daughter__bo0__cmE__bc']>pd_df['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[ (pd_df1['daughter__bo0__cmE__bc']>pd_df1['daughter__bo1__cmE__bc']) ]['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(-1,0)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
#plt.hist(pd_df['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=plot_bins,  histtype='step', density=False, hatch="//")

ax = plt.gca()
ax.set_xlim(-1,1)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.yscale('log')
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
total=pd_df1.shape[0]

# %%
hard_is_bigger=pd_df1[ (pd_df1['daughter__bo0__cmE__bc']>pd_df1['daughter__bo1__cmE__bc'])].shape[0]

# %%
hard_fraction=hard_is_bigger/total

# %%
hard_fraction
# Out:
# 0.9818469140015017

# %%
plt.hist(pd_df['cosHelicityAngleMomentum'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']<0.6].daughter__bo1__cmE__bc, label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[pd_df1['daughter__bo1__cmE__bc']<0.6].daughter__bo1__cmE__bc, label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,0.6)   
xlabel = r'$\mathrm{E}_{\gamma_{soft}}$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterTheta__bc'], label=r'$\pi^0$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterTheta__bc'], label=r'not $\pi^0$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterTheta of $\gamma_s$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterNHits__bc'], label=r'$\pi^0$ like',bins=80,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterNHits__bc'], label=r'not $\pi^0$ like',bins=80,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterNHits of $\gamma_s$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterE9E21__bc'], label=r'$\pi^0$ like',bins=40,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterE9E21__bc'], label=r'not $\pi^0$ like',bins=40,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterE9E21 of $\gamma_s$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper left')

# %%
plt.hist(pd_df['daughter__bo1__cmminC2TDist__bc'], label=r'$\pi^0$ like',bins=80,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmminC2TDist__bc'], label=r'not $\pi^0$ like',bins=80,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'minC2TDist of $\gamma_s$'
plot_title = r'variable of $\pi^0$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
#eta
file='/media/jykim/ssd_T5/storage/workspace/06_MVA/my_pi0etaveto/train_v1/etaveto_train.root'
#file='/group/belle/users/jaeyoung/storage/pi0etaveto/frac_0_3/merged_frac_0_3/pi0etaveto_all_generic_recon_output.root'
file2='/media/jykim/ssd_T5/storage/pi0etaveto/signal/frac_0_5_a/half_1M_0_recon_mdst_all.root'

base_filter='isSignal==1'
base_filter2='isSignal!=1 && daughter__bo0__cmgenMotherPDG__bc==421'
tree='eta'
variables=['M','cosHelicityAngleMomentum','daughter__bo1__cmE__bc','daughter__bo1__cmclusterTheta__bc','daughter__bo1__cmclusterNHits__bc',\
           'daughter__bo1__cmclusterE9E21__bc','daughter__bo1__cmminC2TDist__bc']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
pd_df1 = get_data(file=file2, tree=tree,variables=variables ,base_filter=base_filter2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 13>()
#       9 variables=['M','cosHelicityAngleMomentum','daughter__bo1__cmE__bc','daughter__bo1__cmclusterTheta__bc','daughter__bo1__cmclusterNHits__bc',\
#      10            'daughter__bo1__cmclusterE9E21__bc','daughter__bo1__cmminC2TDist__bc']
#      12 pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
# ---> 13 pd_df1 = get_data(file=file2, tree=tree,variables=variables ,base_filter=base_filter2)
#
# Input In [1], in get_data(file, figname, tree, base_filter, variables)
#      28 base_filter  = base_filter
#      30 ROOT_df_start = ROOT.RDataFrame(tree, f)
# ---> 31 col_dict  = ROOT_df_start.AsNumpy(variables)
#      33 if base_filter !=None:
#      34     ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)
#
# File ~/anaconda3/envs/draw/lib/python3.10/site-packages/ROOT/_pythonization/_rdataframe.py:87, in RDataFrameAsNumpy(df, columns, exclude, lazy)
#      85     return result
#      86 else:
# ---> 87     return result.GetValue()
#
# File ~/anaconda3/envs/draw/lib/python3.10/site-packages/ROOT/_pythonization/_rdataframe.py:133, in AsNumpyResult.GetValue(self)
#     131 self._py_arrays = {}
#     132 for column in self._columns:
# --> 133     cpp_reference = self._result_ptrs[column].GetValue()
#     134     if hasattr(cpp_reference, "__array_interface__"):
#     135         tmp = numpy.asarray(cpp_reference) # This adopts the memory of the C++ object.
#
# KeyboardInterrupt:

# %%
# file='/home/belle2/jaeyoung/workspace/06_MVA/my_pi0etaveto/train_v1/pi0veto_train.root'
file='/media/jykim/ssd_T5/storage/workspace/06_MVA/my_pi0etaveto/train_v1/etaveto_train.root'



# file='/group/belle/users/jaeyoung/storage/pi0etaveto/frac_0_3/merged_frac_0_3/pi0etaveto_all_generic_recon_output.root'
# file2='/group/belle/users/jaeyoung/storage/pi0etaveto/signal/frac_0_5_a/half_1M_0_recon_mdst_all.root'
file2='/media/jykim/ssd_T5/storage/pi0etaveto/signal/frac_0_5_a/half_1M_0_recon_mdst_all.root'



#base_filter='isSignal==1 && M<0.4'
#base_filter2='isSignal!=1 && M<0.4'
base_filter='isSignal==1'
# base_filter2='isSignal!=1 && daughter__bo0__cmgenMotherPDG__bc==421'
base_filter2='isSignal!=1'

tree='eta'
variables=['M','cosHelicityAngleMomentum','daughter__bo1__cmE__bc','daughter__bo1__cmclusterTheta__bc','daughter__bo1__cmclusterNHits__bc',\
           'daughter__bo1__cmclusterE9E21__bc','daughter__bo1__cmminC2TDist__bc','daughter__bo1__cmclusterZernikeMVA__bc']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
pd_df1 = get_data(file=file2, tree=tree,variables=variables ,base_filter=base_filter2)

# %%
plt.hist(pd_df['daughter__bo1__cmclusterZernikeMVA__bc'], label=r'$\eta$ like',bins=100,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterZernikeMVA__bc'],label=r'not $\eta$ like',bins=100,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,1.0)   
xlabel = r"soft photon's clusterZernikeMVA"
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color`='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['M']<1.5].M, label=r'$\eta$ like',bins=100,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[pd_df1['M']<1.5].M, label=r'not $\eta$ like',bins=100,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,1.5)   
xlabel = r'$M(\gamma\gamma)$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color`='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['cosHelicityAngleMomentum'], label=r'$\eta$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['cosHelicityAngleMomentum'], label=r'not $\eta$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'cosHelicityAngleMomentum'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df[pd_df['daughter__bo1__cmE__bc']<0.6].daughter__bo1__cmE__bc, label=r'$\eta$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1[pd_df1['daughter__bo1__cmE__bc']<0.6].daughter__bo1__cmE__bc, label=r'not $\eta$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
ax.set_xlim(0,0.6)   
xlabel = r'$\mathrm{E}_{\gamma_{soft}}$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterTheta__bc'], label=r'$\eta$ like',bins=50,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterTheta__bc'], label=r'not $\eta$ like',bins=50,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterTheta of $\gamma_s$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterNHits__bc'], label=r'$\eta$ like',bins=80,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterNHits__bc'], label=r'not $\eta$ like',bins=80,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterNHits of $\gamma_s$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
plt.hist(pd_df['daughter__bo1__cmclusterE9E21__bc'], label=r'$\eta$ like',bins=40,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmclusterE9E21__bc'], label=r'not $\eta$ like',bins=40,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'clusterE9E21 of $\gamma_s$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper left')

# %%
plt.hist(pd_df['daughter__bo1__cmminC2TDist__bc'], label=r'$\eta$ like',bins=80,  histtype='stepfilled', density=True, hatch="//") 
plt.hist(pd_df1['daughter__bo1__cmminC2TDist__bc'], label=r'not $\eta$ like',bins=80,  histtype='step', density=True, hatch="//")

ax = plt.gca()
#ax.set_xlim(0,0.4)   
xlabel = r'minC2TDist of $\gamma_s$'
plot_title = r'variable of $\eta$ veto'
ax.set_xlabel(xlabel)
plt.title(plot_title)
#plt.axvline(x=1.0395,  color='red', linestyle='dotted')
#plt.axvline(x=0.9995,  color='red', linestyle='dotted')
plt.legend(loc='upper right')

# %%
file ='/home/belle2/jaeyoung/workspace/04_gen/bkg_not_exist/done/D2pippimpi0/ntuple/recon_mdst_e6.root'
file1='/group/belle/users/jaeyoung/storage/01_recon/rho/pid_0_5_signalMC_recon_mdst_rho.root'
base_filter='(D0_M>1.665 && D0_M<2.065) && ( abs(Rho_M- 0.77526) < 0.245 ) && gamma_E>0.55 & Dstarp_CMS_p>2.72 && abs(Dstarp_Q-0.00593)<0.0006'
#base_filter += '&& (gamma_genMotherPDG==111) && (\Phi_genMotherPDG=421) && (gamma_genMotherID==Phi_genMotherID)'
base_filter1='(Dstarp_isSignal==1) && (D0_M>1.665 && D0_M<2.065) && ( abs(Rho_M- 0.77526) < 0.245 ) && gamma_E>0.55 & Dstarp_CMS_p>2.72 && abs(Dstarp_Q-0.00593)<0.0006'


tree='rho'
variables=['D0_M']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
pd_df1 = get_data(file=file1, tree=tree,variables=variables ,base_filter=base_filter)

print(pd_df)
#plt.hist(pd_df['D0_M'], label=r'$D^0 \rightarrow \rho^0(\pi^+ \pi^-) \pi^0$',bins=100,  histtype='step') 
plt.hist(pd_df1['D0_M'], label=r'$D^0 \rightarrow \rho^0(\pi^+ \pi^-) \gamma$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(1.665, 2.065)   
xlabel = r'$M(D^0)$'
plot_title = '1M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# /tmp/ipykernel_219391/1056677567.py in <module>
#       9 variables=['D0_M']
#      10
# ---> 11 pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
#      12 pd_df1 = get_data(file=file1, tree=tree,variables=variables ,base_filter=base_filter)
#      13
#
# /tmp/ipykernel_219391/3171019017.py in get_data(file, figname, tree, base_filter, variables)
#      10     if base_filter !=None:
#      11         ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)
# ---> 12         col_dict  = ROOT_df_filtered.AsNumpy(variables)
#      13
#      14     pd_df  = pd.DataFrame(col_dict)
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      81     py_arrays = {}
#      82     for column in columns:
# ---> 83         cpp_reference = result_ptrs[column].GetValue()
#      84         if hasattr(cpp_reference, "__array_interface__"):
#      85             tmp = numpy.asarray(cpp_reference) # This adopts the memory of the C++ object.
#
# runtime_error: const vector<double>& ROOT::RDF::RResultPtr<vector<double> >::GetValue() =>
#     runtime_error:
# An error occurred during just-in-time compilation in RLoopManager::Run. The lines above might indicate the cause of the crash
# All RDF objects that have not run their event loop yet should be considered in an invalid state.
# IncrementalExecutor::executeFunction: symbol '_ZN4ROOT8Internal3RDF13CacheLineStepIiEEmv' unresolved while linking [cling interface function]!
# You are probably missing the definition of unsigned long ROOT::Internal::RDF::CacheLineStep<int>()
# Maybe you need to load the corresponding shared library?
# IncrementalExecutor::executeFunction: symbol '_ZSt4moveIRSt10shared_ptrIN4ROOT6Detail3RDF9RNodeBaseEEEONSt16remove_referenceIT_E4typeEOS8_' unresolved while linking [cling interface function]!
# You are probably missing the definition of std::remove_reference<std::shared_ptr<ROOT::Detail::RDF::RNodeBase>&>::type&& std::move<std::shared_ptr<ROOT::Detail::RDF::RNodeBase>&>(std::shared_ptr<ROOT::Detail::RDF::RNodeBase>&)
# Maybe you need to load the corresponding shared library?
# IncrementalExecutor::executeFunction: symbol '_ZSt4fillIN9__gnu_cxx17__normal_iteratorIPySt6vectorIySaIyEEEEiEvT_S7_RKT0_' unresolved while linking [cling interface function]!
# You are probably missing the definition of void std::fill<__gnu_cxx::__normal_iterator<unsigned long long*, std::vector<unsigned long long, std::allocator<unsigned long long> > >, int>(__gnu_cxx::__normal_iterator<unsigned long long*, std::vector<unsigned long long, std::allocator<unsigned long long> > >, __gnu_cxx::__normal_iterator<unsigned long long*, std::vector<unsigned long long, std::allocator<unsigned long long> > >, int const&)
# Maybe you need to load the corresponding shared library?

# %%
file='/home/belle2/jaeyoung/workspace/06_MVA/my_pi0etaveto/train_v1/etaveto_train.root'
tree='eta'
variables=['M']
base_filter='isSignal==1'
pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
#pd_df1 = get_data(file=file1, tree=tree,variables=variables ,base_filter=base_filter)

print(pd_df)
plt.hist(pd_df['M'], label=r'$D^0 \rightarrow \rho^0(\pi^+ \pi^-) \pi^0$',bins=100,  histtype='step') 
#plt.hist(pd_df1['D0_M'], label=r'$D^0 \rightarrow \rho^0(\pi^+ \pi^-) \gamma$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(1.665, 2.065)   
xlabel = r'$M(D^0)$'
plot_title = '1M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# SegmentationViolation                     Traceback (most recent call last)
# /tmp/ipykernel_219391/2578735000.py in <module>
#       3 variables=['M']
#       4 base_filter='isSignal==1'
# ----> 5 pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
#       6 #pd_df1 = get_data(file=file1, tree=tree,variables=variables ,base_filter=base_filter)
#       7
#
# /tmp/ipykernel_219391/3171019017.py in get_data(file, figname, tree, base_filter, variables)
#      10     if base_filter !=None:
#      11         ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)
# ---> 12         col_dict  = ROOT_df_filtered.AsNumpy(variables)
#      13
#      14     pd_df  = pd.DataFrame(col_dict)
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      81     py_arrays = {}
#      82     for column in columns:
# ---> 83         cpp_reference = result_ptrs[column].GetValue()
#      84         if hasattr(cpp_reference, "__array_interface__"):
#      85             tmp = numpy.asarray(cpp_reference) # This adopts the memory of the C++ object.
#
# SegmentationViolation: const vector<double>& ROOT::RDF::RResultPtr<vector<double> >::GetValue() =>
#     SegmentationViolation: segfault in C++; program state was reset
#  *** Break *** segmentation violation
#
#
#
# ===========================================================
# There was a crash.
# This is the entire stack trace of all threads:
# ===========================================================
#
# Thread 24 (Thread 0x7fa6fc7c8700 (LWP 226210) "ZMQbg/IO/0"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa91b069ddf in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #2  0x00007fa91b089d99 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #3  0x00007fa91b0b2014 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #4  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #5  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 23 (Thread 0x7fa6f3fc7700 (LWP 226209) "ZMQbg/Reaper"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa91b069ddf in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #2  0x00007fa91b089d99 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #3  0x00007fa91b0b2014 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #4  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #5  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 22 (Thread 0x7fa6eb7c6700 (LWP 226208) "python3.8"):
# #0  0x00007fa923d4bccd in poll () from /lib64/libc.so.6
# #1  0x00007fa91b09aec3 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #2  0x00007fa91b0713a3 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #3  0x00007fa91b0a09c8 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #4  0x00007fa91b0a04dd in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #5  0x00007fa91b0c69c6 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #6  0x00007fa91b0c7200 in zmq_msg_recv () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #7  0x00007fa919c6a48f in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
# #8  0x00007fa919c6718a in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
# #9  0x00007fa91a2b656c in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/error.cpython-38-x86_64-linux-gnu.so
# #10 0x00007fa924c1e887 in _PyObject_MakeTpCall (callable=0x7fa919c56930, args=<optimized out>, nargs=<optimized out>, keywords=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:159
# #11 0x00007fa924c21cc0 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa8cf10b7b0, callable=0x7fa919c56930) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:125
# #12 _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa8cf10b7b0, callable=0x7fa919c56930) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:115
# #13 method_vectorcall (method=<optimized out>, args=0x7fa8cf10b7b8, nargsf=<optimized out>, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:60
# #14 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #15 call_function (tstate=tstate
# entry=0x7fa90800b1a0, pp_stack=pp_stack
# entry=0x7fa6eb7c5958, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #16 0x00007fa924bf9395 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3469
# #17 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #18 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #19 call_function (tstate=tstate
# entry=0x7fa90800b1a0, pp_stack=pp_stack
# entry=0x7fa6eb7c5b38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #20 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #21 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #22 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #23 call_function (tstate=tstate
# entry=0x7fa90800b1a0, pp_stack=pp_stack
# entry=0x7fa6eb7c5d18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #24 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #25 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #26 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa6eb7c5e28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #27 method_vectorcall (method=method
# entry=0x7fa8ec6a7780, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #28 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa8ec6a7780, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #29 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa8ec6a1c30) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #30 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #31 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #32 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 21 (Thread 0x7fa6eafc5700 (LWP 222260) "python3.8"):
# #0  0x00007fa92473ade2 in pthread_cond_timedwait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa924cf757b in PyCOND_TIMEDWAIT (us=<optimized out>, mut=0x7fa924efa150 <_PyRuntime+1232>, cond=0x7fa924efa120 <_PyRuntime+1184>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/condvar.h:73
# #2  take_gil (ceval=ceval
# entry=0x7fa924ef9ec8 <_PyRuntime+584>, tstate=tstate
# entry=0x635bc60) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval_gil.h:206
# #3  0x00007fa924cf7905 in PyEval_RestoreThread (tstate=tstate
# entry=0x635bc60) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:399
# #4  0x00007fa924d9a1b2 in pysleep (secs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/timemodule.c:1867
# #5  time_sleep (self=<optimized out>, obj=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/timemodule.c:338
# #6  0x00007fa924c60772 in cfunction_vectorcall_O (func=0x7fa925066f40, args=0x7fa614000ee8, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/methodobject.c:482
# #7  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #8  call_function (tstate=tstate
# entry=0x635bc60, pp_stack=pp_stack
# entry=0x7fa6eafc4388, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #9  0x00007fa924bf9395 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3469
# #10 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa8ec702b80, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa9143c47d0, kwcount=0, kwstep=1, defs=0x7fa8ec703da8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7fa8ec708130, qualname=0x7fa8ec7064e0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #11 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=<optimized out>, stack=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #12 0x00007fa924c21c8a in _PyObject_Vectorcall (kwnames=0x0, nargsf=2, args=0x7fa9143c47c0, callable=0x7fa8ec71c8b0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #13 method_vectorcall (method=<optimized out>, args=0x7fa9143c47c8, nargsf=<optimized out>, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:60
# #14 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #15 call_function (tstate=tstate
# entry=0x635bc60, pp_stack=pp_stack
# entry=0x7fa6eafc46e8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #16 0x00007fa924bf9395 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3469
# #17 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=2, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #18 0x00007fa924c21c8a in _PyObject_Vectorcall (kwnames=0x0, nargsf=2, args=0x7fa8ecc25f48, callable=0x7fa8ec71b550) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #19 method_vectorcall (method=<optimized out>, args=0x7fa8ecc25f50, nargsf=<optimized out>, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:60
# #20 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #21 call_function (tstate=tstate
# entry=0x635bc60, pp_stack=pp_stack
# entry=0x7fa6eafc4960, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #22 0x00007fa924bf69a2 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3500
# #23 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #24 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #25 call_function (tstate=tstate
# entry=0x635bc60, pp_stack=pp_stack
# entry=0x7fa6eafc4b38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #26 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #27 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #28 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #29 call_function (tstate=tstate
# entry=0x635bc60, pp_stack=pp_stack
# entry=0x7fa6eafc4d18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #30 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #31 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #32 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa6eafc4e28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #33 method_vectorcall (method=method
# entry=0x7fa6cf9b5780, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #34 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa6cf9b5780, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #35 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa8ec72cc00) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #36 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #37 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #38 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 20 (Thread 0x7fa6ca908700 (LWP 222135) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 19 (Thread 0x7fa6cb109700 (LWP 222134) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 18 (Thread 0x7fa6cb90a700 (LWP 222133) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 17 (Thread 0x7fa6cc10b700 (LWP 222132) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 16 (Thread 0x7fa6cc90c700 (LWP 222131) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 15 (Thread 0x7fa6cd10d700 (LWP 222130) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 14 (Thread 0x7fa6cd90e700 (LWP 222129) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 13 (Thread 0x7fa6ce10f700 (LWP 222128) "python3.8"):
# #0  0x00007fa92473aa35 in pthread_cond_wait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa6ce17493f in th_worker (tidptr=<optimized out>) at numexpr/module.cpp:60
# #2  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #3  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 12 (Thread 0x7fa9057fa700 (LWP 219409) "python3.8"):
# #0  0x00007fa92473ade2 in pthread_cond_timedwait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa924cf757b in PyCOND_TIMEDWAIT (us=<optimized out>, mut=0x7fa924efa150 <_PyRuntime+1232>, cond=0x7fa924efa120 <_PyRuntime+1184>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/condvar.h:73
# #2  take_gil (ceval=ceval
# entry=0x7fa924ef9ec8 <_PyRuntime+584>, tstate=tstate
# entry=0x1497900) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval_gil.h:206
# #3  0x00007fa924cf7905 in PyEval_RestoreThread (tstate=tstate
# entry=0x1497900) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:399
# #4  0x00007fa924d9a1b2 in pysleep (secs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/timemodule.c:1867
# #5  time_sleep (self=<optimized out>, obj=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/timemodule.c:338
# #6  0x00007fa924c60772 in cfunction_vectorcall_O (func=0x7fa925066f40, args=0x7fa9143b31d0, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/methodobject.c:482
# #7  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #8  call_function (tstate=tstate
# entry=0x1497900, pp_stack=pp_stack
# entry=0x7fa9057f9958, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #9  0x00007fa924bf9395 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3469
# #10 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #11 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #12 call_function (tstate=tstate
# entry=0x1497900, pp_stack=pp_stack
# entry=0x7fa9057f9b38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #13 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #14 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #15 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #16 call_function (tstate=tstate
# entry=0x1497900, pp_stack=pp_stack
# entry=0x7fa9057f9d18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #17 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #18 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #19 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa9057f9e28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #20 method_vectorcall (method=method
# entry=0x7fa91441dbc0, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #21 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa91441dbc0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #22 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa9144136f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #23 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #24 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #25 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 11 (Thread 0x7fa905ffb700 (LWP 219406) "python3.8"):
# #0  0x00007fa92473ade2 in pthread_cond_timedwait
#
# GLIBC_2.3.2 () from /lib64/libpthread.so.0
# #1  0x00007fa924cf757b in PyCOND_TIMEDWAIT (us=<optimized out>, mut=0x7fa924efa150 <_PyRuntime+1232>, cond=0x7fa924efa120 <_PyRuntime+1184>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/condvar.h:73
# #2  take_gil (ceval=ceval
# entry=0x7fa924ef9ec8 <_PyRuntime+584>, tstate=tstate
# entry=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval_gil.h:206
# #3  0x00007fa924cf7905 in PyEval_RestoreThread (tstate=tstate
# entry=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:399
# #4  0x00007fa91843f5db in pysqlite_step (statement=0x7fa8f400d418, connection=connection
# entry=0x7fa91731a7b0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_sqlite/util.c:38
# #5  0x00007fa91843aab0 in pysqlite_connection_commit (args=<optimized out>, self=0x7fa91731a7b0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_sqlite/connection.c:432
# #6  pysqlite_connection_commit (self=0x7fa91731a7b0, args=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_sqlite/connection.c:412
# #7  0x00007fa924c60c86 in cfunction_vectorcall_NOARGS (func=0x7fa9183a3c70, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/methodobject.c:459
# #8  0x00007fa924c1f1c7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=0, args=0x0, callable=0x7fa9183a3c70) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #9  _PyObject_CallNoArg (func=0x7fa9183a3c70) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:153
# #10 _PyObject_CallFunctionVa (callable=0x7fa9183a3c70, format=<optimized out>, va=<optimized out>, is_size_t=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:915
# #11 0x00007fa924c1f875 in callmethod (is_size_t=1, va=0x7fa905ff9768, format=0x0, callable=0x7fa9183a3c70) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:1011
# #12 _PyObject_CallMethod_SizeT (obj=obj
# entry=0x7fa91731a7b0, name=<optimized out>, format=format
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:1104
# #13 0x00007fa91843994d in pysqlite_connection_exit (self=0x7fa91731a7b0, args=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_sqlite/connection.c:1762
# #14 0x00007fa924c1e1a7 in cfunction_call_varargs (func=0x7fa8cf1a9e00, args=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:758
# #15 0x00007fa924c1e887 in _PyObject_MakeTpCall (callable=0x7fa8cf1a9e00, args=<optimized out>, nargs=<optimized out>, keywords=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:159
# #16 0x00007fa924bf944e in _PyObject_Vectorcall (kwnames=0x0, nargsf=3, args=0x7fa905ff99d0, callable=0x7fa8cf1a9e00) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:125
# #17 _PyObject_Vectorcall (kwnames=0x0, nargsf=3, args=0x7fa905ff99d0, callable=0x7fa8cf1a9e00) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:115
# #18 _PyObject_FastCall (nargs=3, args=0x7fa905ff99d0, func=0x7fa8cf1a9e00) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:147
# #19 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3361
# #20 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=2, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #21 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #22 call_function (tstate=tstate
# entry=0x10e27d0, pp_stack=pp_stack
# entry=0x7fa905ff9b88, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #23 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #24 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa9183db540, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa8ec699c28, kwcount=0, kwstep=1, defs=0x7fa9183e7e08, defcount=1, kwdefs=0x0, closure=0x0, name=0x7fa9183ea3b0, qualname=0x7fa9183ebdf0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #25 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=func
# entry=0x7fa918388310, stack=<optimized out>, nargsf=nargsf
# entry=2, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #26 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa918388310, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #27 0x00007fa924bf4fa6 in do_call_core (kwdict=0x7fa8ec689bc0, callargs=0x7fa8ec699c00, func=0x7fa918388310, tstate=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:5010
# #28 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3559
# #29 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa9183db540, locals=locals
# entry=0x0, args=<optimized out>, argcount=3, kwnames=0x0, kwargs=0x7fa8ec68c370, kwcount=0, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0, name=0x7fa9183e5cb0, qualname=0x7fa9183e5cb0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #30 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=func
# entry=0x7fa9183ec3a0, stack=<optimized out>, nargsf=nargsf
# entry=3, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #31 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa9183ec3a0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #32 0x00007fa924bf4fa6 in do_call_core (kwdict=0x7fa8ec689700, callargs=0x7fa8ec68c340, func=0x7fa9183ec3a0, tstate=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:5010
# #33 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3559
# #34 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa918494d80, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa916c6eef0, kwcount=0, kwstep=1, defs=0x7fa9183e7e08, defcount=1, kwdefs=0x0, closure=0x7fa9184013b0, name=0x7fa9183ea3b0, qualname=0x7fa9183ebdf0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #35 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=<optimized out>, stack=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #36 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #37 call_function (tstate=tstate
# entry=0x10e27d0, pp_stack=pp_stack
# entry=0x7fa905ffa3d8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #38 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #39 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #40 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa9183884c0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #41 0x00007fa924bf4fa6 in do_call_core (kwdict=0x7fa916c71280, callargs=0x7fa91d4478b0, func=0x7fa9183884c0, tstate=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:5010
# #42 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3559
# #43 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa9183db540, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa916c90528, kwcount=0, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0, name=0x7fa9183e5cb0, qualname=0x7fa9183e5cb0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #44 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=func
# entry=0x7fa9183ec3a0, stack=<optimized out>, nargsf=nargsf
# entry=2, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #45 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa9183ec3a0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #46 0x00007fa924bf4fa6 in do_call_core (kwdict=0x7fa916c71840, callargs=0x7fa916c90500, func=0x7fa9183ec3a0, tstate=0x10e27d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:5010
# #47 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3559
# #48 0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa918494d80, locals=locals
# entry=0x0, args=<optimized out>, argcount=1, kwnames=0x0, kwargs=0x7fa916c66dc0, kwcount=0, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x7fa9184014f0, name=0x7fa925073670, qualname=0x7fa9183ebf80) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #49 0x00007fa924c1e62f in _PyFunction_Vectorcall (func=<optimized out>, stack=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #50 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #51 call_function (tstate=tstate
# entry=0x10e27d0, pp_stack=pp_stack
# entry=0x7fa905ffab38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #52 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #53 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #54 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #55 call_function (tstate=tstate
# entry=0x10e27d0, pp_stack=pp_stack
# entry=0x7fa905ffad18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #56 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #57 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #58 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa905ffae28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #59 method_vectorcall (method=method
# entry=0x7fa916c6c080, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #60 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa916c6c080, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #61 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa916c60c90) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #62 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #63 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #64 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 10 (Thread 0x7fa9067fc700 (LWP 219405) "python3.8"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa924f4565a in select_epoll_poll_impl (maxevents=<optimized out>, timeout_obj=<optimized out>, self=0x7fa916c99af0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/selectmodule.c:1558
# #2  select_epoll_poll (self=0x7fa916c99af0, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/clinic/selectmodule.c.h:863
# #3  0x00007fa924c289da in method_vectorcall_FASTCALL_KEYWORDS (func=0x7fa91d3fb1d0, args=0xa4cde68, nargsf=<optimized out>, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/descrobject.c:371
# #4  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #5  call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fb0e8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #6  0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #7  0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa91d3f5800, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa8f0000f20, kwcount=0, kwstep=1, defs=0x7fa91d3ff538, defcount=1, kwdefs=0x0, closure=0x0, name=0x7fa91d3d6230, qualname=0x7fa91d400800) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #8  0x00007fa924c1e62f in _PyFunction_Vectorcall (func=<optimized out>, stack=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #9  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #10 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fb3b8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #11 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #12 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #13 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #14 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fb598, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #15 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #16 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #17 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #18 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fb778, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #19 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #20 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #21 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #22 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fb958, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #23 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #24 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #25 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #26 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fbb38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #27 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #28 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #29 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #30 call_function (tstate=tstate
# entry=0x123b100, pp_stack=pp_stack
# entry=0x7fa9067fbd18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #31 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #32 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #33 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa9067fbe28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #34 method_vectorcall (method=method
# entry=0x7fa916c428c0, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #35 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa916c428c0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #36 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa916c37db0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #37 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #38 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #39 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 9 (Thread 0x7fa906ffd700 (LWP 219404) "python3.8"):
# #0  0x00007fa92473d75d in read () from /lib64/libpthread.so.0
# #1  0x00007fa924d53076 in _Py_read (fd=fd
# entry=41, buf=0x7fa8fc000b30, count=count
# entry=1000) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/fileutils.c:1552
# #2  0x00007fa924d5fe76 in os_read_impl (module=<optimized out>, length=1000, fd=41) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/posixmodule.c:8837
# #3  os_read (module=<optimized out>, nargs=<optimized out>, args=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/clinic/posixmodule.c.h:4726
# #4  os_read (module=<optimized out>, args=<optimized out>, nargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/clinic/posixmodule.c.h:4691
# #5  0x00007fa924c60b73 in cfunction_vectorcall_FASTCALL (func=0x7fa925051270, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/methodobject.c:422
# #6  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #7  call_function (tstate=tstate
# entry=0x1249a40, pp_stack=pp_stack
# entry=0x7fa906ffc6f8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# ...
# #18 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #19 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #20 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa915430e28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #21 method_vectorcall (method=method
# entry=0x7fa916ca5f00, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #22 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa916ca5f00, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #23 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa916c3d3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #24 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #25 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #26 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 4 (Thread 0x7fa915c32700 (LWP 219399) "python3.8"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa924f4565a in select_epoll_poll_impl (maxevents=<optimized out>, timeout_obj=<optimized out>, self=0x7fa916c99bd0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/selectmodule.c:1558
# #2  select_epoll_poll (self=0x7fa916c99bd0, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/clinic/selectmodule.c.h:863
# #3  0x00007fa924c289da in method_vectorcall_FASTCALL_KEYWORDS (func=0x7fa91d3fb1d0, args=0x5db7208, nargsf=<optimized out>, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/descrobject.c:371
# #4  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #5  call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c30e88, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #6  0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #7  0x00007fa924cf8624 in _PyEval_EvalCodeWithName (_co=<optimized out>, globals=globals
# entry=0x7fa91d3f5800, locals=locals
# entry=0x0, args=<optimized out>, argcount=2, kwnames=0x0, kwargs=0x7fa908000f20, kwcount=0, kwstep=1, defs=0x7fa91d3ff538, defcount=1, kwdefs=0x0, closure=0x0, name=0x7fa91d3d6230, qualname=0x7fa91d400800) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4298
# #8  0x00007fa924c1e62f in _PyFunction_Vectorcall (func=<optimized out>, stack=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:436
# #9  0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #10 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c31158, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #11 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #12 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #13 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #14 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c31338, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #15 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #16 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #17 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #18 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c31518, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #19 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #20 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #21 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #22 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c316f8, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #23 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #24 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #25 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa915c31808, callable=0x7fa9177bbee0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #26 method_vectorcall (method=method
# entry=0x7fa916cab080, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #27 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa916cab080, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #28 0x00007fa924bf4fa6 in do_call_core (kwdict=0x7fa916ca9f80, callargs=0x7fa9250b1040, func=0x7fa916cab080, tstate=0x12032a0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:5010
# #29 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3559
# #30 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #31 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #32 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c31b38, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #33 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #34 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #35 0x00007fa924bf1d56 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #36 call_function (tstate=tstate
# entry=0x12032a0, pp_stack=pp_stack
# entry=0x7fa915c31d18, oparg=<optimized out>, kwnames=kwnames
# entry=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:4963
# #37 0x00007fa924bf3ee1 in _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/ceval.c:3486
# #38 0x00007fa924bf0a7b in function_code_fastcall (co=<optimized out>, args=<optimized out>, nargs=1, globals=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:284
# #39 0x00007fa924c21d0b in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7fa915c31e28, callable=0x7fa91d3f60d0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Include/cpython/abstract.h:127
# #40 method_vectorcall (method=method
# entry=0x7fa916cab3c0, args=0x7fa9250b1058, nargsf=nargsf
# entry=0, kwnames=0x0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/classobject.c:67
# #41 0x00007fa924c2044c in PyVectorcall_Call (callable=0x7fa916cab3c0, tuple=<optimized out>, kwargs=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Objects/call.c:200
# #42 0x00007fa924d9b84d in t_bootstrap (boot_raw=boot_raw
# entry=0x7fa916ca1030) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Modules/_threadmodule.c:1002
# #43 0x00007fa924d45ec7 in pythread_wrapper (arg=<optimized out>) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/python/Python/thread_pthread.h:232
# #44 0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #45 0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 3 (Thread 0x7fa916433700 (LWP 219398) "ZMQbg/IO/0"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa91b069ddf in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #2  0x00007fa91b089d99 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #3  0x00007fa91b0b2014 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #4  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #5  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 2 (Thread 0x7fa916c34700 (LWP 219397) "ZMQbg/Reaper"):
# #0  0x00007fa923d56fd3 in epoll_wait () from /lib64/libc.so.6
# #1  0x00007fa91b069ddf in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #2  0x00007fa91b089d99 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #3  0x00007fa91b0b2014 in ?? () from /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/lib/python3.8/site-packages/zmq/backend/cython/../../../pyzmq.libs/libzmq-68c212d3.so.5.2.4
# #4  0x00007fa924736ea5 in start_thread () from /lib64/libpthread.so.0
# #5  0x00007fa923d569fd in clone () from /lib64/libc.so.6
#
# Thread 1 (Thread 0x7fa9250f1740 (LWP 219391) "python3.8"):
# #0  0x00007fa923d1d549 in waitpid () from /lib64/libc.so.6
# #1  0x00007fa923c9af62 in do_system () from /lib64/libc.so.6
# #2  0x00007fa923c9b311 in system () from /lib64/libc.so.6
# #3  0x00007fa6265c984c in TUnixSystem::Exec (shellcmd=<optimized out>, this=0x1039c30) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/core/unix/src/TUnixSystem.cxx:2120
# #4  TUnixSystem::StackTrace (this=0x1039c30) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/core/unix/src/TUnixSystem.cxx:2411
# #5  0x00007fa626805dd3 in (anonymous namespace)::do_trace (sig=1) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/bindings/pyroot/cppyy/cppyy-backend/clingwrapper/src/clingwrapper.cxx:182
# #6  (anonymous namespace)::TExceptionHandlerImp::HandleException (this=<optimized out>, sig=1) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/bindings/pyroot/cppyy/cppyy-backend/clingwrapper/src/clingwrapper.cxx:195
# #7  0x00007fa6265c6cd1 in TUnixSystem::DispatchSignals (this=0x1039c30, sig=kSigSegmentationViolation) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/core/unix/src/TUnixSystem.cxx:3644
# #8  <signal handler called>
# #9  0x00007fa8d7801dbd in ?? ()
# #10 0x000000000c7ae100 in ?? ()
# #11 0x000000000c7ae100 in ?? ()
# #12 0x00007fffd03d9600 in ?? ()
# #13 0x00007fa8d7828a33 in ?? ()
# #14 0x00007fffd03d9610 in ?? ()
# #15 0x000000000c736b60 in ?? ()
# #16 0x000000000c62c3f0 in ?? ()
# #17 0x00007fa8ec2099a5 in ROOT::Detail::RDF::RLoopManager::EvalChildrenCounts (this=0x7fffd03d95e0, this
# entry=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:673
# #18 0x00007fa8ec2099ec in ROOT::Detail::RDF::RLoopManager::InitNodes (this=this
# entry=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:598
# #19 0x00007fa8ec211706 in ROOT::Detail::RDF::RLoopManager::Run (this=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:691
# #20 0x00007fa8d785301f in ?? ()
# #21 0x0000000000000000 in ?? ()
# ===========================================================
#
#
# The lines below might hint at the cause of the crash.
# You may get help by asking at the ROOT forum https://root.cern.ch/forum
# Only if you are really convinced it is a bug in ROOT then please submit a
# report at https://root.cern.ch/bugs Please post the ENTIRE stack trace
# from above as an attachment in addition to anything else
# that might help us fixing this issue.
# ===========================================================
# #9  0x00007fa8d7801dbd in ?? ()
# #10 0x000000000c7ae100 in ?? ()
# #11 0x000000000c7ae100 in ?? ()
# #12 0x00007fffd03d9600 in ?? ()
# #13 0x00007fa8d7828a33 in ?? ()
# #14 0x00007fffd03d9610 in ?? ()
# #15 0x000000000c736b60 in ?? ()
# #16 0x000000000c62c3f0 in ?? ()
# #17 0x00007fa8ec2099a5 in ROOT::Detail::RDF::RLoopManager::EvalChildrenCounts (this=0x7fffd03d95e0, this
# entry=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:673
# #18 0x00007fa8ec2099ec in ROOT::Detail::RDF::RLoopManager::InitNodes (this=this
# entry=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:598
# #19 0x00007fa8ec211706 in ROOT::Detail::RDF::RLoopManager::Run (this=0xc62c3f0) at /cvmfs/belle.cern.ch/el7/externals/v01-11-00/src/root/tree/dataframe/src/RLoopManager.cxx:691
# #20 0x00007fa8d785301f in ?? ()
# #21 0x0000000000000000 in ?? ()
# ===========================================================

# %%
#file = '/group/belle/users/jaeyoung/storage/01_recon/train/recon_output.root'
#file = '/home/jykim/nas/storage/01_recon/merge_generic_bkg/ccbar/train_v1_yes_signal_ccbar_recon_output_02.root'
file = '/home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root'
#file = '/home/jykim/nas/storage/01_recon/merge_generic_bkg/ccbar/topo_pid_0_5_no_signal_ccbar_recon_output_00.root'
tree = 'antiKstar'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#base_filter = '(Dstarp_isSignal==1) && '+ Filter['antiKstar']
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Pi0_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Pi0_Prob'], label=r'$\bar{K}^{*0}$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\pi^0$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# /tmp/ipykernel_219391/2945995375.py in <module>
#       9 variables=['Pi0_Prob']
#      10
# ---> 11 pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
#      12
#      13 plt.hist(pd_df['Pi0_Prob'], label=r'$\bar{K}^{*0}$',bins=100,  histtype='step')
#
# /tmp/ipykernel_219391/3171019017.py in get_data(file, figname, tree, base_filter, variables)
#       6
#       7     ROOT_df_start = ROOT.RDataFrame(tree, f)
# ----> 8     col_dict  = ROOT_df_start.AsNumpy(variables)
#       9
#      10     if base_filter !=None:
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      75     result_ptrs = {}
#      76     for column in columns:
# ---> 77         column_type = df.GetColumnType(column)
#      78         result_ptrs[column] = df.Take[column_type](column)
#      79
#
# runtime_error: string ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::GetColumnType(basic_string_view<char,char_traits<char> > column) =>
#     runtime_error: Column "Pi0_Prob" is not in a dataset and is not a custom column been defined.
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root does not exist

# %%
#file = '/group/belle/users/jaeyoung/storage/01_recon/train/recon_output.root'
#file = '/home/jykim/nas/storage/01_recon/merge_generic_bkg/ccbar/train_v1_yes_signal_ccbar_recon_output_02.root'
file = '/home/jykim/nas/storage/01_recon/antiKstar/expert_signalMC_recon_mdst_antiKstar.root'
#file = '/home/jykim/nas/storage/01_recon/merge_generic_bkg/ccbar/topo_pid_0_5_no_signal_ccbar_recon_output_00.root'
tree = 'antiKstar'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#base_filter = 'Dstarp_isSignal==1 && ' + Filter['antiKstar']
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Eta_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Eta_Prob'], label=r'$\bar{K}^{*0}$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\eta$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()

# %%
file = '/home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root'
tree = 'rho'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Pi0_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Pi0_Prob'], label=r'$\rho^0$',bins=100,  histtype='stepfilled', hatch="//") 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\pi^0$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# /tmp/ipykernel_11334/1983338137.py in <module>
#       5 variables=['Pi0_Prob']
#       6
# ----> 7 pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)
#       8
#       9 plt.hist(pd_df['Pi0_Prob'], label=r'$\rho^0$',bins=100,  histtype='stepfilled', hatch="//")
#
# /tmp/ipykernel_11334/3171019017.py in get_data(file, figname, tree, base_filter, variables)
#       6
#       7     ROOT_df_start = ROOT.RDataFrame(tree, f)
# ----> 8     col_dict  = ROOT_df_start.AsNumpy(variables)
#       9
#      10     if base_filter !=None:
#
# /cvmfs/belle.cern.ch/el7/externals/v01-11-00/Linux_x86_64/common/root/lib/ROOT/pythonization/_rdataframe.py in RDataFrameAsNumpy(df, columns, exclude)
#      75     result_ptrs = {}
#      76     for column in columns:
# ---> 77         column_type = df.GetColumnType(column)
#      78         result_ptrs[column] = df.Take[column_type](column)
#      79
#
# runtime_error: string ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::GetColumnType(basic_string_view<char,char_traits<char> > column) =>
#     runtime_error: Column "Pi0_Prob" is not in a dataset and is not a custom column been defined.
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root does not exist
# Error in <TFile::TFile>: file /home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root does not exist

# %%
file = '/home/jykim/nas/storage/01_recon/rho/expert_signalMC_recon_mdst_rho.root'
tree = 'rho'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Eta_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Eta_Prob'], label=r'$\rho^0$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\eta$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()

# %%
file = '/home/jykim/nas/storage/01_recon/omega/expert_signalMC_recon_mdst_omega.root'
tree = 'omega'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Pi0_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Pi0_Prob'], label=r'$\omega$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\pi^0$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()

# %%
file = '/home/jykim/nas/storage/01_recon/omega/expert_signalMC_recon_mdst_omega.root'
tree = 'omega'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Eta_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Eta_Prob'], label=r'$\omega$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\eta$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()

# %%
file = '/home/jykim/nas/storage/01_recon/phi/expert_signalMC_recon_mdst_phi.root'
tree = 'phi'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Pi0_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

plt.hist(pd_df['Pi0_Prob'], label=r'$\phi$',bins=100,  histtype='step') 
ax = plt.gca()
ax.set_xlim(0, 1)   
xlabel = r'$\pi^0$ Prob'
plot_title = '0.5M Signal MC'

ax.set_xlabel(xlabel)
plt.title(plot_title)
plt.legend()

# %%
file = '/home/jykim/nas/storage/01_recon/phi/expert_signalMC_recon_mdst_phi.root'
tree = 'phi'
base_filter = 'Dstarp_isSignal==1 && gamma_E>0.3 && gamma_clusterSecondMoment<=1.5'
#variables=['pip_E','pim_E','pi0_E','pip_px','pim_px','pi0_px','pip_py','pim_py','pi0_py','pip_pz','pim_pz','pi0_pz']
variables=['Eta_Prob']

pd_df = get_data(file=file, tree=tree,variables=variables ,base_filter=base_filter)

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# some random data
x = np.random.randn(1000)
y = np.random.randn(1000)


def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.25
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figure
fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()

# %%
# start with a square Figure
fig = plt.figure(figsize=(8, 8))

# Add a gridspec with two rows and two columns and a ratio of 2 to 7 between
# the size of the marginal axes and the main axes in both directions.
# Also adjust the subplot parameters for a square plot.
gs = fig.add_gridspec(2, 2,  width_ratios=(7, 2), height_ratios=(2, 7),
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)

ax = fig.add_subplot(gs[1, 0])
ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)

# use the previously defined function
scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()
